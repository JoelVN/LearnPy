# %% [markdown]
# H2 day3 operators
#
# https://github.com/Asabeneh/30-Days-Of-Python/blob/master/03_Day_Operators/03_operators.md

# %%
import math
import sympy as sp

# %%
radius = 10
area_of_circle = 3.14 * radius ** 2  

print(len('mango') == len('avocado'))

print('True == True: ', True == True)
print('True == False: ', True == False)
print('False == False:', False == False)

# %% [markdown]
# In addition to the above comparison operator Python uses:
#
# is: Returns true if both variables are the same object(x is y)
# is not: Returns true if both variables are not the same object(x is not y)
# in: Returns True if the queried list contains a certain item(x in y)
# not in: Returns True if the queried list doesn't have a certain item(x in y)

# %%
print('1 is 1', 1 is 1)                   # True - because the data values are the same
print('1 is not 2', 1 is not 2)           # True - because 1 is not 2
print('A in Asabeneh', 'A' in 'Asabeneh') # True - A found in the string
print('B in Asabeneh', 'B' in 'Asabeneh') # False - there is no uppercase B
print('coding' in 'coding for all')

# %% [markdown]
# Excercises
# 1.Declare your age as integer variable
# 2.Declare your height as a float variable
# 3.Declare a variable that store a complex number
# 4.Write a script that prompts the user to enter base and height of the triangle and calculate an area of this triangle (area = 0.5 x b x h).

# %%
age = 26
height = 1.80
complex_number = 1.3 + 3j

# %%
base = float(input("Ingrese base: "))
height = float(input("Ingrese altura: "))
area = 0.5 * base * height
print(area)

# %% [markdown]
# Write a script that prompts the user to enter side a, side b, and side c of the triangle. Calculate the perimeter of the triangle (perimeter = a + b + c).

# %%
a = float(input("Ingrese a: "))
b = float(input("Ingrese b: "))
c = float(input("Ingrese c: "))
perimeter = a + b + c
perimeter

# %% [markdown]
# Get length and width of a rectangle using prompt. Calculate its area (area = length x width) and perimeter (perimeter = 2 x (length + width))

# %%
length = float(input("Ingrese length: "))
width = float(input("Ingrese width: "))
perimeter = 2 * (length + width)
perimeter

# %% [markdown]
# Calculate the slope, x-intercept and y-intercept of y = 2x -2

# %%
#coeficiente de ecuación lineal y = mx + b
# y = mx + b
# y = 2x - 2
m = 2 
b = -2 

#calculo de la pendiente ( slope) 
pendiente = m 

#calculo del x-intercept (punto de intersección en el eje x) y es 0
x_intercept = -b / m 

#calculo del y-intercept (punto de intersección en el eje y) x es 0 
y_intercept = -b 

print("Pendiente:", pendiente)
print("x_intercept:", x_intercept)
print("y_intercept:", y_intercept)

# %% [markdown]
# Slope is (m = y2-y1/x2-x1). Find the slope and Euclidean distance between point (2, 2) and point (6,10)

# %%
# puntos (2, 2) and  (6,10)
x1,y1 = 2,2
x2,y2 = 6,10

#calcular pendiente (slope)
slope = (y2 - y1) / (x2 - x1)

# distancia euclidean
distancia = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)

# Imprimir los resultados
print("Pendiente:", slope)
print("Distancia Euclidiana:", distancia)

# %%
print(pendiente == slope)

# %% [markdown]
# Calculate the value of y (y = x^2 + 6x + 9). Try to use different x values and figure out at what x value y is going to be 0.

# %%
# Definir la variable simbólica x y la ecuación
x = sp.symbols('x')
ecuacion = x**2 + 6*x + 9

# Resolver la ecuación para encontrar las raíces (valores de x donde y = 0)
raices = sp.solve(ecuacion, x)

# Imprimir las raíces
print("Las raíces son:", raices)

# Calcular los valores de y para las raíces encontradas
valores_de_y = [ecuacion.subs(x, raiz) for raiz in raices]

# Imprimir los valores de y correspondientes a las raíces
for i, raiz in enumerate(raices):
    print(f"Para x = {raiz}, y = {valores_de_y[i]}")
# Out:
# Las raíces son: [-3]
# Para x = -3, y = 0

# %% [markdown]
# Find the length of 'python' and 'dragon' and make a falsy comparison statement.

# %%
print(len("python") == len("dragon"))
# Out:
# True

# %% [markdown]
# Find the length of 'python' and 'dragon' and make a falsy comparison statement.

# %%
print("esta on en la palabra python: ","on" in "python")
print("esta on en la palabra dragon: ", "on" in "dragon")
# Out:
# esta on en la palabra python:  True
# esta on en la palabra dragon:  True

# %% [markdown]
# I hope this course is not full of jargon. Use in operator to check if jargon is in the sentence.

# %%
print("esta jargon en la frase 'I hope this course is not full of jargon': ", "jargon" in "I hope this course is not full of jargon")
# Out:
# esta jargon en la frase 'I hope this course is not full of jargon':  True

# %% [markdown]
# There is no 'on' in both dragon and python

# %%
# Definir las cadenas
cadena1 = "dragon"
cadena2 = "python"

# Verificar si 'on' está presente en ambas cadenas
if 'on' in cadena1 and 'on' in cadena2:
    print("La subcadena 'on' está presente en ambas cadenas.")
else:
    print("La subcadena 'on' no está presente en ambas cadenas.")
# Out:
# La subcadena 'on' está presente en ambas cadenas.

# %% [markdown]
# There is no 'on' in both dragon and python

# %%
to_float = float(len(cadena2))
print(to_float)
to_string = str(to_float)
print(to_string)
# Out:
# 6.0
# 6.0

# %% [markdown]
# Even numbers are divisible by 2 and the remainder is zero. How do you check if a number is even or not using python?

# %%
def es_par(number):
    return number % 2 == 0 

num = int(input("Ingrese valor a validar :"))

if es_par(num):
    print(f"el numero {num} es par")
else:
    print(f"el numero {num} no es par")
# Out:
# el numero 6 es par

# %% [markdown]
# Check if the floor division of 7 by 3 is equal to the int converted value of 2.7.

# %%
result = 7//3 == int(2.7)
if result:
    print("el valor es igual")
else:
    print("el valor no es igual")
# Out:
# el valor es igual

# %% [markdown]
# Check if type of '10' is equal to type of 10

# %%
result1 = type("10") == type(10)
st = type("10")
entero = type(10)

if result1:
    print(f"el tipo de dato de type(10) es {st} y es igual a type(10) {entero}")
else:
    print(f"el tipo de dato de type(10) es {st} y no es igual a type(10) {entero}")
# Out:
# el tipo de dato de type(10) es <class 'str'> y no es igual a type(10) <class 'int'>
